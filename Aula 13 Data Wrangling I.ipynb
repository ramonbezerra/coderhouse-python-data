# %% [markdown]
# # Data Wrangling I
#
# Data Wrangling é um processo manual para transformar dados brutos em um formato adequado para análise.
# ETL é um processo automatizado projetado para integrar, limpar e preencher dados em um repositório, normalmente um data warehouse. Embora a organização de dados seja exploratória e iterativa, o ETL é sistemático e definido.
#
# ## Coleta de Dados
#
# A partir da lista de ativos da API Alpha Vantage em conjunto com a biblioteca Yahoo Finance, vamos criar uma nova base de dados com as ações, informando os dividendos dos últimos 5 anos.

# %%
import pandas as pd

df = pd.read_csv('listing_status.csv', header=0)
df.head(10)
# Out:
#     symbol                                               name   exchange  \
# 0        A                           Agilent Technologies Inc       NYSE
# 1       AA                                         Alcoa Corp       NYSE
# 2      AAA    ALTERNATIVE ACCESS FIRST PRIORITY CLO BOND ETF   NYSE ARCA
# 3     AAAU                    Goldman Sachs Physical Gold ETF       BATS
# 4     AACG                              ATA Creativity Global     NASDAQ
# 5     AACT          Ares Acquisition Corporation II - Class A       NYSE
# 6   AACT-U  Ares Acquisition Corporation II - Units (1 Ord...       NYSE
# 7  AACT-WS  Ares Acquisition Corporation II - Warrants (01...       NYSE
# 8     AADI                                Aadi Bioscience Inc     NASDAQ
# 9     AADR               ADVISORSHARES DORSEY WRIGHT ADR ETF      NASDAQ
#
#   assetType     ipoDate  delistingDate  status
# 0     Stock  1999-11-18            NaN  Active
# 1     Stock  2016-10-18            NaN  Active
# 2       ETF  2020-09-09            NaN  Active
# 3       ETF  2018-08-15            NaN  Active
# 4     Stock  2008-01-29            NaN  Active
# 5     Stock  2023-06-12            NaN  Active
# 6     Stock  2023-04-21            NaN  Active
# 7     Stock  2023-06-12            NaN  Active
# 8     Stock  2017-08-08            NaN  Active
# 9       ETF  2010-07-21            NaN  Active

# %%
#! pip install yfinance
import yfinance as yf

def get_finance_data_name(symbol):
    try:
        return yf.Ticker(symbol).info['shortName']
    except:
        return f''

# %% [markdown]
# ## Limpeza e Transformação dos Dados
#
# Faremos um processo mais minucioso de limpeza dos dados, pois sabemos que há muitas inconsistências de tipos:

# %%
df.dtypes
# Out:
# symbol            object
# name              object
# exchange          object
# assetType         object
# ipoDate           object
# delistingDate    float64
# status            object
# dtype: object

# %% [markdown]
# E também de dados ausentes:

# %%
df.isna().sum()
# Out:
# symbol               1
# name                34
# exchange             0
# assetType            0
# ipoDate              0
# delistingDate    11628
# status               0
# dtype: int64

# %%
df.loc[df.name.isna()]
# Out:
#         symbol name   exchange assetType     ipoDate  delistingDate  status
# 456       AMEH  NaN     NASDAQ     Stock  2024-02-26            NaN  Active
# 487       AMRS  NaN     NASDAQ     Stock  2023-08-18            NaN  Active
# 896       AVRO  NaN     NASDAQ     Stock  2024-06-21            NaN  Active
# 2113      CLVS  NaN     NASDAQ     Stock  2023-01-03            NaN  Active
# 2419     CTEST  NaN       NYSE     Stock  2019-07-25            NaN  Active
# 2632       DEC  NaN       NYSE     Stock  2023-12-18            NaN  Active
# 2676      DFFN  NaN     NASDAQ     Stock  2023-08-17            NaN  Active
# 4135       FWP  NaN     NASDAQ     Stock  2022-12-27            NaN  Active
# 6994     MTEST  NaN       NYSE     Stock  2019-10-09            NaN  Active
# 7401   NTEST-G  NaN       NYSE     Stock  2019-07-17            NaN  Active
# 7402   NTEST-H  NaN       NYSE     Stock  2019-07-12            NaN  Active
# 7403   NTEST-I  NaN       NYSE     Stock  2019-07-12            NaN  Active
# 7404   NTEST-J  NaN       NYSE     Stock  2019-07-12            NaN  Active
# 7405   NTEST-K  NaN       NYSE     Stock  2019-07-12            NaN  Active
# 7406   NTEST-L  NaN       NYSE     Stock  2019-07-17            NaN  Active
# 7407   NTEST-M  NaN       NYSE     Stock  2019-07-15            NaN  Active
# 7408   NTEST-N  NaN       NYSE     Stock  2019-07-16            NaN  Active
# 7409   NTEST-O  NaN       NYSE     Stock  2019-07-17            NaN  Active
# 7410   NTEST-P  NaN       NYSE     Stock  2019-06-24            NaN  Active
# 7411   NTEST-Q  NaN       NYSE     Stock  2019-07-17            NaN  Active
# 7412   NTEST-Y  NaN       NYSE     Stock  2019-07-30            NaN  Active
# 7413   NTEST-Z  NaN       NYSE     Stock  2019-07-30            NaN  Active
# 8412   PTEST-A  NaN  NYSE ARCA     Stock  2021-09-13            NaN  Active
# 8413   PTEST-W  NaN  NYSE ARCA     Stock  2018-10-29            NaN  Active
# 8414   PTEST-X  NaN  NYSE ARCA     Stock  2019-08-30            NaN  Active
# 8415   PTEST-Y  NaN  NYSE ARCA     Stock  2019-08-30            NaN  Active
# 8619      QTNT  NaN     NASDAQ     Stock  2023-01-03            NaN  Active
# 9756      SPWR  NaN     NASDAQ     Stock  2024-08-21            NaN  Active
# 10090     TCDA  NaN     NASDAQ     Stock  2023-01-23            NaN  Active
# 10275     TMDI  NaN     NASDAQ     Stock  2023-03-09            NaN  Active
# 10548     UCBI  NaN     NASDAQ     Stock  2024-07-29            NaN  Active
# 11604    ZTEST  NaN       BATS     Stock  2011-10-05            NaN  Active
# 11609     ZTST  NaN       BATS     Stock  2015-10-19            NaN  Active
# 11626      ZZK  NaN  NYSE ARCA     Stock  2020-07-22            NaN  Active

# %%
df.loc[df.symbol.isna()]
# Out:
#      symbol           name exchange assetType     ipoDate  delistingDate  \
# 7073    NaN  Nano Labs Ltd   NASDAQ     Stock  2022-07-12            NaN
#
#       status
# 7073  Active

# %% [markdown]
# Vamos corrigir esses tipos para lidar melhor com essas informações:

# %%
df['ipoDate'] = pd.to_datetime(df['ipoDate'], format='%Y-%m-%d')
df['delistingDate'] = pd.to_datetime(df['delistingDate'], format='%Y-%m-%d')
df['assetType'] = df['assetType'].astype('category')
df['exchange'] = df['exchange'].astype('category')
df['name'] = df['name'].astype('string')

# %%
df.dtypes
# Out:
# symbol                   object
# name             string[python]
# exchange               category
# assetType              category
# ipoDate          datetime64[ns]
# delistingDate    datetime64[ns]
# status                   object
# dtype: object

# %% [markdown]
# ## Integração dos Dados
#
# Para cada linha com nome nulo, vamos recuperar essa informação com a função do Yahoo Finance. Para as que não forem possíveis de recuperar, vamos excluir essas linhas:

# %%
df['name'] = df.apply(lambda x: get_finance_data_name(x.symbol) if pd.isna(x['name']) or x['name'] == '' else x.name, axis=1)

df.dropna(subset=['name', 'symbol'], inplace=True)
df.drop(df[df.name == ''].index, inplace=True)

df.shape
# Out:
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/AMEH?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=AMEH&crumb=H1YgLak2O95
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/DFFN?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=DFFN&crumb=H1YgLak2O95
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NTEST-G?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NTEST-G&crumb=H1YgLak2O95
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NTEST-J?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NTEST-J&crumb=H1YgLak2O95
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NTEST-K?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NTEST-K&crumb=H1YgLak2O95
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NTEST-L?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NTEST-L&crumb=H1YgLak2O95
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NTEST-M?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NTEST-M&crumb=H1YgLak2O95
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NTEST-N?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NTEST-N&crumb=H1YgLak2O95
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NTEST-O?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NTEST-O&crumb=H1YgLak2O95
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NTEST-P?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NTEST-P&crumb=H1YgLak2O95
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/NTEST-Q?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=NTEST-Q&crumb=H1YgLak2O95
# 404 Client Error: Not Found for url: https://query2.finance.yahoo.com/v10/finance/quoteSummary/PTEST-A?modules=financialData%2CquoteType%2CdefaultKeyStatistics%2CassetProfile%2CsummaryDetail&corsDomain=finance.yahoo.com&formatted=false&symbol=PTEST-A&crumb=H1YgLak2O95
# (11598, 7)

# %% [markdown]
# Vamos também excluir as duplicatas de nomes:

# %%
# df.drop_duplicates(subset=['name'], inplace=True)
# df.shape
# Out:
# (11598, 7)

# %% [markdown]
# Agora vamos integrar à nossa base de dados informações sobre os dividendos pagos pelas empresas e ETF's nos últimos 5 anos:

# %%
def get_dividends_by_period(period, symbol):
    try: 
        return yf.Ticker(symbol).history(period=period).Dividends.sum() # 1d, 1w, 1m, 3m, 6m, 5y, 10y, ytd, max
    except:
        return 0

# %%
def get_history_by_period(period, symbol):
    try:
        return yf.Ticker(symbol).history(period=period)
    except:
        return pd.DataFrame()

get_history_by_period('5y', 'AAPL')
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2019-09-18 00:00:00-04:00   53.476841   53.909864   53.084947   53.890511
# 2019-09-19 00:00:00-04:00   53.706659   54.130004   53.309925   53.452656
# 2019-09-20 00:00:00-04:00   53.554269   53.839722   52.608396   52.671291
# 2019-09-23 00:00:00-04:00   52.966417   53.181717   52.651931   52.910778
# 2019-09-24 00:00:00-04:00   53.469579   53.822771   52.540642   52.659176
# ...                               ...         ...         ...         ...
# 2024-09-11 00:00:00-04:00  221.460007  223.089996  217.889999  222.660004
# 2024-09-12 00:00:00-04:00  222.500000  223.550003  219.820007  222.770004
# 2024-09-13 00:00:00-04:00  223.580002  224.039993  221.910004  222.500000
# 2024-09-16 00:00:00-04:00  216.539993  217.220001  213.919998  216.320007
# 2024-09-17 00:00:00-04:00  215.750000  216.899994  214.500000  216.789993
#
#                               Volume  Dividends  Stock Splits
# Date
# 2019-09-18 00:00:00-04:00  101360000        0.0           0.0
# 2019-09-19 00:00:00-04:00   88242400        0.0           0.0
# 2019-09-20 00:00:00-04:00  221652400        0.0           0.0
# 2019-09-23 00:00:00-04:00   76662000        0.0           0.0
# 2019-09-24 00:00:00-04:00  124763200        0.0           0.0
# ...                              ...        ...           ...
# 2024-09-11 00:00:00-04:00   44587100        0.0           0.0
# 2024-09-12 00:00:00-04:00   37498200        0.0           0.0
# 2024-09-13 00:00:00-04:00   36766600        0.0           0.0
# 2024-09-16 00:00:00-04:00   59357400        0.0           0.0
# 2024-09-17 00:00:00-04:00   45487304        0.0           0.0
#
# [1258 rows x 7 columns]

# %% [markdown]
# ## Redução e Validação dos Dados
#
# Vamos extrair uma amostra aleatória para iniciar a comparação do desempenho nominal dos dividendos dos últimos 5 anos entre as bolsas.

# %%
sample_df = df.sample(n=25)
sample_df
# Out:
#        symbol  name   exchange assetType    ipoDate delistingDate  status
# 3568      FAS  3568  NYSE ARCA       ETF 2008-11-19           NaT  Active
# 4083     FTIF  4083  NYSE ARCA       ETF 2023-03-14           NaT  Active
# 4198    GATEU  4198     NASDAQ     Stock 2021-10-01           NaT  Active
# 6543      MBI  6543       NYSE     Stock 1987-07-02           NaT  Active
# 7134      NCL  7134   NYSE MKT     Stock 2023-10-19           NaT  Active
# 8716     RDIV  8716  NYSE ARCA       ETF 2013-10-01           NaT  Active
# 7421     NTRA  7421     NASDAQ     Stock 2015-07-02           NaT  Active
# 2028      CIM  2028       NYSE     Stock 2007-11-16           NaT  Active
# 3981     FPRO  3981       BATS       ETF 2021-02-04           NaT  Active
# 5189     IDAT  5189  NYSE ARCA       ETF 2021-06-10           NaT  Active
# 6195      LEG  6195       NYSE     Stock 1987-11-05           NaT  Active
# 9461     SKIL  9461       NYSE     Stock 2019-07-26           NaT  Active
# 1522     BSCS  1522     NASDAQ       ETF 2018-08-09           NaT  Active
# 7760     ORCL  7760       NYSE     Stock 1986-03-12           NaT  Active
# 5247      IGF  5247     NASDAQ       ETF 2007-12-12           NaT  Active
# 983      BAMG   983       BATS       ETF 2023-09-27           NaT  Active
# 9679      SPE  9679       NYSE       ETF 1994-10-27           NaT  Active
# 4806  HGTY-WS  4806       NYSE     Stock 2021-12-03           NaT  Active
# 7765      ORI  7765       NYSE     Stock 1990-03-26           NaT  Active
# 4952     HSMV  4952  NYSE ARCA       ETF 2020-04-07           NaT  Active
# 3754      FHN  3754       NYSE     Stock 1990-03-26           NaT  Active
# 6381     LRGC  6381  NYSE ARCA       ETF 2023-09-20           NaT  Active
# 9582     SNCY  9582     NASDAQ     Stock 2021-03-17           NaT  Active
# 8189     PMAX  8189     NASDAQ     Stock 2024-09-05           NaT  Active
# 6545    MBINM  6545     NASDAQ     Stock 2022-09-23           NaT  Active

# %%
sample_df['dividends_last_5_years'] = sample_df.apply(lambda x: get_dividends_by_period('5y', x.symbol), axis=1)
sample_df
# Out:
# FTIF: Period '5y' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', 'ytd', 'max']
# NCL: Period '5y' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', 'ytd', 'max']
# BAMG: Period '5y' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', 'ytd', 'max']
# $HGTY-WS: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
# LRGC: Period '5y' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', 'ytd', 'max']
# PMAX: Period '5y' is invalid, must be one of ['1d', '5d', '1mo', 'ytd', 'max']
# MBINM: Period '5y' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', 'ytd', 'max']
#        symbol  name   exchange assetType    ipoDate delistingDate  status  \
# 3568      FAS  3568  NYSE ARCA       ETF 2008-11-19           NaT  Active
# 4083     FTIF  4083  NYSE ARCA       ETF 2023-03-14           NaT  Active
# 4198    GATEU  4198     NASDAQ     Stock 2021-10-01           NaT  Active
# 6543      MBI  6543       NYSE     Stock 1987-07-02           NaT  Active
# 7134      NCL  7134   NYSE MKT     Stock 2023-10-19           NaT  Active
# 8716     RDIV  8716  NYSE ARCA       ETF 2013-10-01           NaT  Active
# 7421     NTRA  7421     NASDAQ     Stock 2015-07-02           NaT  Active
# 2028      CIM  2028       NYSE     Stock 2007-11-16           NaT  Active
# 3981     FPRO  3981       BATS       ETF 2021-02-04           NaT  Active
# 5189     IDAT  5189  NYSE ARCA       ETF 2021-06-10           NaT  Active
# 6195      LEG  6195       NYSE     Stock 1987-11-05           NaT  Active
# 9461     SKIL  9461       NYSE     Stock 2019-07-26           NaT  Active
# 1522     BSCS  1522     NASDAQ       ETF 2018-08-09           NaT  Active
# 7760     ORCL  7760       NYSE     Stock 1986-03-12           NaT  Active
# 5247      IGF  5247     NASDAQ       ETF 2007-12-12           NaT  Active
# 983      BAMG   983       BATS       ETF 2023-09-27           NaT  Active
# 9679      SPE  9679       NYSE       ETF 1994-10-27           NaT  Active
# 4806  HGTY-WS  4806       NYSE     Stock 2021-12-03           NaT  Active
# 7765      ORI  7765       NYSE     Stock 1990-03-26           NaT  Active
# 4952     HSMV  4952  NYSE ARCA       ETF 2020-04-07           NaT  Active
# 3754      FHN  3754       NYSE     Stock 1990-03-26           NaT  Active
# 6381     LRGC  6381  NYSE ARCA       ETF 2023-09-20           NaT  Active
# 9582     SNCY  9582     NASDAQ     Stock 2021-03-17           NaT  Active
# 8189     PMAX  8189     NASDAQ     Stock 2024-09-05           NaT  Active
# 6545    MBINM  6545     NASDAQ     Stock 2022-09-23           NaT  Active
#
#       dividends_last_5_years
# 3568                   4.091
# 4083                   0.000
# 4198                   0.000
# 6543                   8.000
# 7134                   0.000
# 8716                   7.406
# 7421                   0.000
# 2028                  17.210
# 3981                   1.927
# 5189                   0.616
# 6195                   7.780
# 9461                   0.000
# 1522                   3.252
# 7760                   6.400
# 5247                   6.586
# 983                    0.000
# 9679                   6.610
# 4806                   0.000
# 7765                   8.115
# 4952                   1.494
# 3754                   2.990
# 6381                   0.000
# 9582                   0.000
# 8189                   0.000
# 6545                   0.000

# %% [markdown]
# Como a amostra aleatória trouxe muitas empresas novas, sem histórico de dividendos mínimo consistente para a nossa análise, vamos tentar refinar nossa amostra. Antes, vamos verificar a proporção de ativos por exchange e por tipo:

# %%
rate_exchange = df.exchange.value_counts(normalize=True)
rate_exchange
# Out:
# exchange
# NASDAQ       0.447319
# NYSE         0.263063
# NYSE ARCA    0.192792
# BATS         0.068633
# NYSE MKT     0.028195
# Name: proportion, dtype: float64

# %%
rate_asset = df.assetType.value_counts(normalize=True)
rate_asset
# Out:
# assetType
# Stock    0.644853
# ETF      0.355147
# Name: proportion, dtype: float64

# %% [markdown]
# Para fins de simplificação, vamos deixar somente as exchanges mais conhecidas e verificar a proporção novamente:

# %%
df.drop(df[df.exchange == 'NYSE ARCA'].index, inplace=True)
df.drop(df[df.exchange == 'NYSE MKT'].index, inplace=True)
df.drop(df[df.exchange == 'BATS'].index, inplace=True)

# %%
rate_exchange = df.exchange.value_counts(normalize=True)
rate_exchange
# Out:
# exchange
# NASDAQ       0.629688
# NYSE         0.370312
# BATS         0.000000
# NYSE ARCA    0.000000
# NYSE MKT     0.000000
# Name: proportion, dtype: float64

# %% [markdown]
# Agora vamos extrair uma amostra obedecendo essas proporções:

# %%
exchange_sample = df.groupby('exchange').apply(lambda x: x.sample(int(10 * rate_exchange[x.name]))).droplevel('exchange')
exchange_sample
# Out:
# C:\Users\premier-improvement\AppData\Local\Temp\ipykernel_19524\2489681502.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   exchange_sample = df.groupby('exchange').apply(lambda x: x.sample(int(10 * rate_exchange[x.name]))).droplevel('exchange')
# C:\Users\premier-improvement\AppData\Local\Temp\ipykernel_19524\2489681502.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   exchange_sample = df.groupby('exchange').apply(lambda x: x.sample(int(10 * rate_exchange[x.name]))).droplevel('exchange')
#      symbol  name exchange assetType    ipoDate delistingDate  status
# 2957   DVAX  2957   NASDAQ     Stock 2004-02-19           NaT  Active
# 3488   EWCZ  3488   NASDAQ     Stock 2021-08-05           NaT  Active
# 7265   NKLA  7265   NASDAQ     Stock 2018-06-11           NaT  Active
# 2232   COLM  2232   NASDAQ     Stock 1998-03-27           NaT  Active
# 8488   PYPD  8488   NASDAQ     Stock 2020-06-26           NaT  Active
# 6505    MAR  6505   NASDAQ     Stock 1993-10-13           NaT  Active
# 1989    CHN  1989     NYSE       ETF 1992-07-10           NaT  Active
# 9491   SLGN  9491     NYSE     Stock 1997-02-14           NaT  Active
# 1355   BMAC  1355     NYSE     Stock 2021-11-12           NaT  Active

# %%
asset_sample = df.groupby('assetType').apply(lambda x: x.sample(int(10 * rate_asset[x.name]))).droplevel('assetType')
asset_sample
# Out:
# C:\Users\premier-improvement\AppData\Local\Temp\ipykernel_19524\3961626324.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   asset_sample = df.groupby('assetType').apply(lambda x: x.sample(int(10 * rate_asset[x.name]))).droplevel('assetType')
# C:\Users\premier-improvement\AppData\Local\Temp\ipykernel_19524\3961626324.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   asset_sample = df.groupby('assetType').apply(lambda x: x.sample(int(10 * rate_asset[x.name]))).droplevel('assetType')
#       symbol   name exchange assetType    ipoDate delistingDate  status
# 10357   TQQQ  10357   NASDAQ       ETF 2010-02-11           NaT  Active
# 8348    PSCE   8348   NASDAQ       ETF 2010-04-07           NaT  Active
# 4795    HFRO   4795     NYSE       ETF 2017-11-06           NaT  Active
# 830     AUDC    830   NASDAQ     Stock 1999-05-28           NaT  Active
# 3266    ENSC   3266   NASDAQ     Stock 2018-02-26           NaT  Active
# 5331   IMKTA   5331   NASDAQ     Stock 1990-03-26           NaT  Active
# 7823   OXLCN   7823   NASDAQ     Stock 2014-06-02           NaT  Active
# 4464    GMRE   4464     NYSE     Stock 2016-06-29           NaT  Active
# 6279    LION   6279   NASDAQ     Stock 2024-05-14           NaT  Active

# %% [markdown]
# Para comparar dividendos, vamos adicionar as informações como anteriormente, em cada sample:

# %%
exchange_sample['dividends_last_5_years'] = exchange_sample.apply(lambda x: get_dividends_by_period('5y', x.symbol), axis=1)
exchange_sample
# Out:
# MKAM: Period '5y' is invalid, must be one of ['1d', '5d', '1mo', '3mo', '6mo', '1y', '2y', 'ytd', 'max']
# $VCXA: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
# $ADAL: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
# $ATH-P-A: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
#         symbol                                               name exchange  \
# 6763      MKAM                                          MKAM ETF    NASDAQ
# 5838      JSML        JANUS HENDERSON SMALL CAP GROWTH ALPHA ETF    NASDAQ
# 3025       EBC                             Eastern Bankshares Inc   NASDAQ
# 10803     VCXA  10X Capital Venture Acquisition Corp II - Class A   NASDAQ
# 122       ADAL     Anthemis Digital Acquisitions I Corp - Class A   NASDAQ
# 10362     TRDA                           Entrada Therapeutics Inc   NASDAQ
# 11151      WES                      Western Midstream Partners LP     NYSE
# 781    ATH-P-A                                 Athene Holding Ltd     NYSE
# 9039      RVTY                                        Revvity Inc     NYSE
#
#       assetType    ipoDate delistingDate  status  dividends_last_5_years
# 6763        ETF 2023-04-12           NaT  Active                   0.000
# 5838        ETF 2016-02-25           NaT  Active                   1.253
# 3025      Stock 2020-10-15           NaT  Active                   1.440
# 10803     Stock 2021-10-05           NaT  Active                   0.000
# 122       Stock 2021-12-29           NaT  Active                   0.000
# 10362     Stock 2021-10-29           NaT  Active                   0.000
# 11151     Stock 2012-12-10           NaT  Active                  10.089
# 781       Stock 2019-06-06           NaT  Active                   0.000
# 9039      Stock 1983-04-06           NaT  Active                   1.400

# %%
asset_sample['dividends_last_5_years'] = asset_sample.apply(lambda x: get_dividends_by_period('5y', x.symbol), axis=1)
asset_sample
# Out:
# VSTEW: Period '5y' is invalid, must be one of ['1d', '5d']
# ASTSW: Period '5y' is invalid, must be one of ['1d', '5d']
#       symbol                                               name exchange  \
# 11075   VYMI  VANGUARD INTERNATIONAL HIGH DIVIDEND YIELD IND...   NASDAQ
# 5338    IMOM  ALPHA ARCHITECT INTERNATIONAL QUANTITATIVE MOM...   NASDAQ
# 5146    IBTF         ISHARES IBONDS DEC 2025 TERM TREASURY ETF    NASDAQ
# 11069   VXRT                                         Vaxart Inc   NASDAQ
# 8877      RM                           Regional Management Corp     NYSE
# 4933     HRI                                  Herc Holdings Inc     NYSE
# 6418   LTRPA        Liberty TripAdvisor Holdings Inc - Series A   NASDAQ
# 11019  VSTEW        Vast Renewables Ltd - Warrants (01/07/2028)   NASDAQ
# 755    ASTSW        AST SpaceMobile Inc - Warrants (06/04/2026)   NASDAQ
#
#       assetType    ipoDate delistingDate  status  dividends_last_5_years
# 11075       ETF 2016-03-02           NaT  Active                  13.541
# 5338        ETF 2016-01-04           NaT  Active                   2.971
# 5146        ETF 2020-02-28           NaT  Active                   2.354
# 11069     Stock 2018-02-12           NaT  Active                   0.000
# 8877      Stock 2012-03-28           NaT  Active                   4.450
# 4933      Stock 2006-11-16           NaT  Active                   7.327
# 6418      Stock 2014-08-27           NaT  Active                   0.000
# 11019     Stock 2023-12-19           NaT  Active                   0.000
# 755       Stock 2019-11-01           NaT  Active                   0.000

# %% [markdown]
# Numa outra tentativa, vamos montar uma amostra considerando empresas listadas entre 5 e 10 anos:

# %%
five_year_df = df[df.ipoDate.dt.year.between(2014, 2019)]
five_year = five_year_df.ipoDate.dt.year.value_counts(normalize=True)

five_year_sample = five_year_df.groupby(five_year_df.ipoDate.dt.year).apply(lambda x: x.sample(int(25 * five_year[x.name]))).droplevel('ipoDate')
five_year_sample['dividends_last_5_years'] = five_year_sample.apply(lambda x: get_dividends_by_period('5y', x.symbol), axis=1)
five_year_sample
# Out:
# $CIO-P-A: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
# $AMH-P-G: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
# $NLY-P-I: possibly delisted; no price data found  (period=5y) (Yahoo error = "No data found, symbol may be delisted")
#         symbol   name exchange assetType    ipoDate delistingDate  status  \
# 3034     EBR-B   3034     NYSE     Stock 2014-09-22           NaT  Active
# 7639       OEC   7639     NYSE     Stock 2014-07-25           NaT  Active
# 9314      SFBS   9314     NYSE     Stock 2014-05-14           NaT  Active
# 70         ACB     70   NASDAQ     Stock 2014-07-11           NaT  Active
# 2027       CIL   2027   NASDAQ       ETF 2015-08-20           NaT  Active
# 11526      YRD  11526     NYSE     Stock 2015-12-18           NaT  Active
# 1450       BOX   1450     NYSE     Stock 2015-01-23           NaT  Active
# 2040   CIO-P-A   2040     NYSE     Stock 2016-10-06           NaT  Active
# 10095     TCMD  10095   NASDAQ     Stock 2016-07-28           NaT  Active
# 11190     WINT  11190   NASDAQ     Stock 2016-01-04           NaT  Active
# 9859      STEL   9859     NYSE     Stock 2017-11-08           NaT  Active
# 11239      WOW  11239     NYSE     Stock 2017-05-25           NaT  Active
# 4734       HCC   4734     NYSE     Stock 2017-04-10           NaT  Active
# 460    AMH-P-G    460     NYSE     Stock 2017-07-11           NaT  Active
# 390       ALLK    390   NASDAQ     Stock 2018-07-19           NaT  Active
# 9856      STCN   9856   NASDAQ     Stock 2018-02-26           NaT  Active
# 11076     VYNE  11076   NASDAQ     Stock 2018-01-25           NaT  Active
# 4874      HNDL   4874   NASDAQ       ETF 2018-01-17           NaT  Active
# 7279   NLY-P-I   7279     NYSE     Stock 2019-06-21           NaT  Active
# 1553      BSMS   1553   NASDAQ       ETF 2019-09-26           NaT  Active
# 3967       FOX   3967   NASDAQ     Stock 2019-03-13           NaT  Active
# 2402      CSTL   2402   NASDAQ     Stock 2019-07-25           NaT  Active
#
#        dividends_last_5_years
# 3034                 1.797644
# 7639                 0.851000
# 9314                 4.590000
# 70                   0.000000
# 2027                 5.619000
# 11526                0.000000
# 1450                 0.000000
# 2040                 0.000000
# 10095                0.000000
# 11190                0.000000
# 9859                 2.550000
# 11239                0.000000
# 4734                 3.890000
# 460                  0.000000
# 390                  0.000000
# 9856                 0.000000
# 11076                0.000000
# 4874                 7.965000
# 7279                 0.000000
# 1553                 1.838000
# 3967                 2.460000
# 2402                 0.000000
